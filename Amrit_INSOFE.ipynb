# %% [markdown]
# <a href="https://colab.research.google.com/github/AmritkumarT/Other-Python-Programs/blob/main/Amrit_INSOFE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Case Study** by INSOFE
# 1.      Read data and understand each attribute clearly
#
# 2.      Prepare customer level data by aggregating the data
#
# (Create customer level aggregated metrics like, number of transactions, number of items purchased, revenue generated by customer, etc.,). Research and define actionable metrics/attributes which will help to explain the customer profile
#
# 3.      Implement cluster analysis using the new attributes created and generate customer segments
#
# ·         Choose optimal clusters
#
# ·         Check cluster stability
#
# ·         Interpret the cluster outcomes
#
# 4.      Consider the raw data and check if there is any significant association between the products and retrieve some useful rules.

# %% [markdown]
# # 1. Read data and understand each attribute clearly
# [A] Observed that given data is a Clean Record i.e No Null Values
#
# [B] Understanding Data(ASSUMPTIONS):
#
#     Location
#
#     Distance
#
#     Store Nearby/Far

# %%
# import pandas as pd
import pandas as pd

import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Takes the file's folder

#Use this if running on Jupyter
#filepath = r"C:\Users\amrit\OneDrive\Desktop\INSOFE\POS_Data.csv"

#Use this if running on Colab
filepath = r"https://raw.githubusercontent.com/AmritkumarT/DATASETS/main/POS_Data.csv"

# read the CSV file
df = pd.read_csv(filepath)

# Checking full Dataset
print(df)

# Printing First five records
#print(df.head())
# Out:
#        RetailStore  CustomerID  ... ProductID     Cost
# 0                1        1001  ...         4   144.75
# 1                2        1002  ...         8    97.25
# 2                2        1002  ...         2    47.25
# 3                2        1002  ...         9   197.25
# 4                3        1003  ...         2   216.00
# ...            ...         ...  ...       ...      ...
# 56793            2       10272  ...        12   207.25
# 56794            5       11329  ...         7   274.50
# 56795            1       10469  ...        14   207.00
# 56796            5       11372  ...        20  1074.75
# 56797            5       11372  ...        20  1074.75
#
# [56798 rows x 6 columns]

# %% [markdown]
# # 2. Prepare customer level data by aggregating the data
# [A] Data Aggregation:
#
# (i) I will count Total Retail Stores & Total Customers
#
# (ii) Using Charts I will prepare Customer Spread
#
# (iii) For ease of analysis, i will set TransactionTime attributre to Labelled data.
#
#       (Eg. 2019-> 0 and 2020-> 1)
#
#       Similarly, Month of the Year (1 to 12) and Day of the Week(1 to 7)
#
# (iv) Prepare Year-wise / Month-wise / Day-wise sales chart
#
# (v) I shall create metrics for:
#
#         -> Number of Products bought per Customer given Transaction
#
#         -> Time & Product, and Time & Customer relationship
#
#     (This shall answer the question that, What time a Product is usually bought by a Customer?)
#
#
# [B] Sales Analysis:
#
# I'll prepare a Box Chart for Sales Analysis to find,
#
# (i) Per RetailStore and Per Customer, How much will be the Sales?
#
# (ii) Per RetailStore and Per Product, How much will be the Sales?
#
# (iii) Per RetailStore, Per Customer and Per Product, How much will be the Sales?

# %%
df.RetailStore.unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
df1=df[['RetailStore','Cost']]
df1=df1.groupby(['RetailStore']).sum()
print(df1)
# Out:
#                    Cost
# RetailStore
# 1            1667968.25
# 2            2462940.50
# 3            1686689.75
# 4            2328376.50
# 5            2227462.25

# %%
#BarChart

# %% [markdown]
# # 3. Implement cluster analysis using the new attributes created and generate customer segments

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=5)

# %%
cluster = km.fit(reduced_data)

# %%
plt.scatter(reduced_data[:, 0], reduced_data[:, 1], label='Datapoints')
plt.scatter(cluster.cluster_centers_[:, 0], cluster.cluster_centers_[:, 1], label='Clusters')
plt.title("Sklearn version of KMeans")
plt.legend()
plt.show()

# %% [markdown]
# # 4. Consider the raw data and check if there is any significant association between the products and retrieve some useful rules.
#
# Here I'll prepare Heat-Map to compare the records from Raw Data to find association between various products.
#
# Analogy: Customer buying Milk also buying Bread.
#
# Example: Customer buying ProductID:4 also buying ProductID:8 etc.
